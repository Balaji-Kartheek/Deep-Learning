# %% [markdown]
# Balaji Kartheek (200968080)

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("bodyfat.csv")
df.head()
# Out:
#    Density  BodyFat  Age  Weight  Height  Neck  Chest  Abdomen    Hip  Thigh  \
# 0   1.0708     12.3   23  154.25   67.75  36.2   93.1     85.2   94.5   59.0
# 1   1.0853      6.1   22  173.25   72.25  38.5   93.6     83.0   98.7   58.7
# 2   1.0414     25.3   22  154.00   66.25  34.0   95.8     87.9   99.2   59.6
# 3   1.0751     10.4   26  184.75   72.25  37.4  101.8     86.4  101.2   60.1
# 4   1.0340     28.7   24  184.25   71.25  34.4   97.3    100.0  101.9   63.2
#
#    Knee  Ankle  Biceps  Forearm  Wrist
# 0  37.3   21.9    32.0     27.4   17.1
# 1  37.3   23.4    30.5     28.9   18.2
# 2  38.9   24.0    28.8     25.2   16.6
# 3  37.3   22.8    32.4     29.4   18.2
# 4  42.2   24.0    32.2     27.7   17.7

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 252 entries, 0 to 251
# Data columns (total 15 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Density  252 non-null    float64
#  1   BodyFat  252 non-null    float64
#  2   Age      252 non-null    int64
#  3   Weight   252 non-null    float64
#  4   Height   252 non-null    float64
#  5   Neck     252 non-null    float64
#  6   Chest    252 non-null    float64
#  7   Abdomen  252 non-null    float64
#  8   Hip      252 non-null    float64
#  9   Thigh    252 non-null    float64
#  10  Knee     252 non-null    float64
#  11  Ankle    252 non-null    float64
#  12  Biceps   252 non-null    float64
#  13  Forearm  252 non-null    float64
#  14  Wrist    252 non-null    float64
# dtypes: float64(14), int64(1)
# memory usage: 29.7 KB

# %%
df.describe()
# Out:
#           Density     BodyFat         Age      Weight      Height        Neck  \
# count  252.000000  252.000000  252.000000  252.000000  252.000000  252.000000
# mean     1.055574   19.150794   44.884921  178.924405   70.148810   37.992063
# std      0.019031    8.368740   12.602040   29.389160    3.662856    2.430913
# min      0.995000    0.000000   22.000000  118.500000   29.500000   31.100000
# 25%      1.041400   12.475000   35.750000  159.000000   68.250000   36.400000
# 50%      1.054900   19.200000   43.000000  176.500000   70.000000   38.000000
# 75%      1.070400   25.300000   54.000000  197.000000   72.250000   39.425000
# max      1.108900   47.500000   81.000000  363.150000   77.750000   51.200000
#
#             Chest     Abdomen         Hip       Thigh        Knee       Ankle  \
# count  252.000000  252.000000  252.000000  252.000000  252.000000  252.000000
# mean   100.824206   92.555952   99.904762   59.405952   38.590476   23.102381
# ...

# %%
df.hist(figsize=(12,14) ,color ='y',edgecolor = 'r')
plt.show()

# %%
df.corr()
# Out:
#           Density   BodyFat       Age    Weight    Height      Neck     Chest  \
# Density  1.000000 -0.987782 -0.277637 -0.594062  0.097881 -0.472966 -0.682599
# BodyFat -0.987782  1.000000  0.291458  0.612414 -0.089495  0.490592  0.702620
# Age     -0.277637  0.291458  1.000000 -0.012746 -0.171645  0.113505  0.176450
# Weight  -0.594062  0.612414 -0.012746  1.000000  0.308279  0.830716  0.894191
# Height   0.097881 -0.089495 -0.171645  0.308279  1.000000  0.253710  0.134892
# Neck    -0.472966  0.490592  0.113505  0.830716  0.253710  1.000000  0.784835
# Chest   -0.682599  0.702620  0.176450  0.894191  0.134892  0.784835  1.000000
# Abdomen -0.798955  0.813432  0.230409  0.887995  0.087813  0.754077  0.915828
# Hip     -0.609331  0.625201 -0.050332  0.940884  0.170394  0.734958  0.829420
# Thigh   -0.553091  0.559608 -0.200096  0.868694  0.148436  0.695697  0.729859
# Knee    -0.495040  0.508665  0.017516  0.853167  0.286053  0.672405  0.719496
# ...

# %%
sns.heatmap(df.corr())
plt.plot()
# Out:
# []

# %%
# outlier_attributes = ['Height','Weight','Neck','Abdomen','Hip','Thigh','Knee','Ankle','Biceps']

# %%
df[df.Weight>300]
# Out:
#     Density  BodyFat  Age  Weight  Height  Neck  Chest  Abdomen    Hip  Thigh  \
# 38   1.0202     35.2   46  363.15   72.25  51.2  136.2    148.1  147.7   87.3
#
#     Knee  Ankle  Biceps  Forearm  Wrist
# 38  49.1   29.6    45.0     29.0   21.4

# %%
def BoxPlot(df):
    for i in df.columns:
        sns.boxplot(df[i])
        plt.show()

# %%
BoxPlot(df)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# ...

# %%
df.skew()
# Out:
# Density   -0.020176
# BodyFat    0.146353
# Age        0.283521
# Weight     1.205263
# Height    -5.384987
# Neck       0.552620
# Chest      0.681556
# Abdomen    0.838418
# Hip        1.497127
# Thigh      0.821210
# Knee       0.516744
# Ankle      2.255134
# Biceps     0.285530
# Forearm   -0.219333
# Wrist      0.281614
# dtype: float64

# %% [markdown]
# # Outliers are handled in the Neural Networks

# %% [markdown]
# ## Normalization

# %%
from sklearn.preprocessing import  MinMaxScaler
scalar = MinMaxScaler()

# %%
df.columns
cols = ['Density', 'BodyFat', 'Age', 'Weight', 'Height', 'Neck', 'Chest',
       'Abdomen', 'Hip', 'Thigh', 'Knee', 'Ankle', 'Biceps', 'Forearm',
       'Wrist']

# %%
df = scalar.fit_transform(df)
df = pd.DataFrame(df,columns = cols)
df
# Out:
#       Density   BodyFat       Age    Weight    Height      Neck     Chest  \
# 0    0.665496  0.258947  0.016949  0.146127  0.792746  0.253731  0.242531
# 1    0.792801  0.128421  0.000000  0.223789  0.886010  0.368159  0.251318
# 2    0.407375  0.532632  0.000000  0.145105  0.761658  0.144279  0.289982
# 3    0.703248  0.218947  0.067797  0.270795  0.886010  0.313433  0.395431
# 4    0.342406  0.604211  0.033898  0.268751  0.865285  0.164179  0.316344
# ..        ...       ...       ...       ...       ...       ...       ...
# 247  0.690079  0.231579  0.813559  0.064378  0.777202  0.189055  0.173989
# 248  0.251097  0.707368  0.847458  0.337216  0.834197  0.487562  0.513181
# 249  0.331870  0.616842  0.847458  0.278970  0.756477  0.388060  0.558875
# 250  0.394205  0.547368  0.847458  0.295320  0.849741  0.388060  0.509666
# 251  0.281826  0.671579  0.881356  0.363785  0.839378  0.482587  0.581722
#
#       Abdomen       Hip     Thigh      Knee     Ankle    Biceps   Forearm  \
# ...

# %% [markdown]
# #### Splitting the dependent and independent features

# %%
X=df.drop('BodyFat',axis = 1)
y = df.BodyFat

# %%
X
# Out:
#       Density       Age    Weight    Height      Neck     Chest   Abdomen  \
# 0    0.665496  0.016949  0.146127  0.792746  0.253731  0.242531  0.200762
# 1    0.792801  0.000000  0.223789  0.886010  0.368159  0.251318  0.172808
# 2    0.407375  0.000000  0.145105  0.761658  0.144279  0.289982  0.235070
# 3    0.703248  0.067797  0.270795  0.886010  0.313433  0.395431  0.216010
# 4    0.342406  0.033898  0.268751  0.865285  0.164179  0.316344  0.388818
# ..        ...       ...       ...       ...       ...       ...       ...
# 247  0.690079  0.813559  0.064378  0.777202  0.189055  0.173989  0.180432
# 248  0.251097  0.847458  0.337216  0.834197  0.487562  0.513181  0.452351
# 249  0.331870  0.847458  0.278970  0.756477  0.388060  0.558875  0.534943
# 250  0.394205  0.847458  0.295320  0.849741  0.388060  0.509666  0.405337
# 251  0.281826  0.881356  0.363785  0.839378  0.482587  0.581722  0.496823
#
#           Hip     Thigh      Knee     Ankle    Biceps   Forearm     Wrist
# ...

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# #### 1. Perform experiments using (70,15,15) split and tabulate the performance in terms of RMSE
# for the following Hyper parameters :

# %%
train_size = 0.7
X_train,X_remaining,y_train,y_remaining = train_test_split(X,y,train_size = 0.7)

# %%
X_test,X_valid,y_test,y_valid = train_test_split(X_remaining,y_remaining,test_size = 0.5)

# %%
print(X_train.shape), print(y_train.shape)
print(X_valid.shape), print(y_valid.shape)
print(X_test.shape), print(y_test.shape)
# Out:
# (176, 14)
# (176,)
# (38, 14)
# (38,)
# (38, 14)
# (38,)
# (None, None)

# %%
X_train[:2]
# Out:
#       Density       Age    Weight    Height      Neck     Chest   Abdomen  \
# 50   0.707638  0.423729  0.162477  0.886010  0.189055  0.191564  0.219822
# 197  0.555751  0.338983  0.202330  0.870466  0.268657  0.223199  0.257942
#
#           Hip     Thigh      Knee     Ankle    Biceps   Forearm     Wrist
# 50   0.212121  0.134663  0.260870  0.222973  0.059406  0.345324  0.267857
# 197  0.255183  0.376559  0.310559  0.216216  0.297030  0.489209  0.196429

# %%
X_train.shape[1]
# Out:
# 14

# %%
import tensorflow as tf

# %% [markdown]
# # WITHOUT REGULARIZATION

# %% [markdown]
# # Model 1 with one hidden Layer

# %%
def model_1(X_train,y_train,epochs_,activations,learning):
    model1 = tf.keras.Sequential()
    model1.add(tf.keras.layers.Flatten(input_shape=[14],name ="Input_Layer"))  
    model1.add(tf.keras.layers.Dense(128,activation = activations,name = "Hidden_Layer_1"))
    model1.add(tf.keras.layers.Dense(1,activation = "linear",kernel_initializer='normal',name = "Output_Layer"))

    opt = tf.keras.optimizers.Adam(learning_rate=learning)

    model1.compile(loss='mean_squared_error', optimizer=opt, metrics = tf.keras.metrics.RootMeanSquaredError())

    model1.fit(X_train,y_train,epochs =epochs_,validation_data=(X_valid, y_valid))

    return model1.evaluate(X_test,y_test)[1]

# %%
epoch_values = []
l_values = []
activ_values = []
rmse = []
regularizers = []

# %%
data = {
    'epochs' : epoch_values,
    'learning_rates' : l_values,
    'activation_function':activ_values,    
    'regularizers' : regularizers,
    'rmse' : rmse

}
result = pd.DataFrame(data)
result
# Out:
# Empty DataFrame
# Columns: [epochs, learning_rates, activation_function, regularizers, rmse]
# Index: []

# %%
result.columns
# Out:
# Index(['epochs', 'learning_rates', 'activation_function', 'regularizers',
#        'rmse'],
#       dtype='object')

# %%
for epochs in [10,20,30,40]:
  for l in [1, 0.3, 0.1, 0.01,0.03,0.001,0.0001,0.00001]:
    for activations in ['relu','sigmoid']:
      
      rmse = model_1(X_train,y_train,epochs,activations,l)
      result.loc[len(result.index)] = [epochs,l,activations,0,rmse]
# Out:
# Epoch 1/10
# 6/6 [==============================] - 2s 30ms/step - loss: 12654.8750 - root_mean_squared_error: 112.4939 - val_loss: 11.1097 - val_root_mean_squared_error: 3.3331
# Epoch 2/10
# 6/6 [==============================] - 0s 7ms/step - loss: 7.3709 - root_mean_squared_error: 2.7149 - val_loss: 9.7884 - val_root_mean_squared_error: 3.1286
# Epoch 3/10
# 6/6 [==============================] - 0s 7ms/step - loss: 10.8793 - root_mean_squared_error: 3.2984 - val_loss: 12.7622 - val_root_mean_squared_error: 3.5724
# Epoch 4/10
# 6/6 [==============================] - 0s 7ms/step - loss: 12.7746 - root_mean_squared_error: 3.5742 - val_loss: 13.1322 - val_root_mean_squared_error: 3.6238
# Epoch 5/10
# 6/6 [==============================] - 0s 8ms/step - loss: 12.4341 - root_mean_squared_error: 3.5262 - val_loss: 11.8207 - val_root_mean_squared_error: 3.4381
# Epoch 6/10
# ...

# %%
result1_0 = result
result1_0
# Out:
#     epochs  learning_rates activation_function  regularizers      rmse
# 0     10.0         1.00000                relu           0.0  1.409797
# 1     10.0         1.00000             sigmoid           0.0  0.530202
# 2     10.0         0.30000                relu           0.0  0.115624
# 3     10.0         0.30000             sigmoid           0.0  0.222239
# 4     10.0         0.10000                relu           0.0  0.089641
# ..     ...             ...                 ...           ...       ...
# 59    40.0         0.00100             sigmoid           0.0  0.117017
# 60    40.0         0.00010                relu           0.0  0.135650
# 61    40.0         0.00010             sigmoid           0.0  0.149460
# 62    40.0         0.00001                relu           0.0  0.327097
# 63    40.0         0.00001             sigmoid           0.0  0.559052
#
# [64 rows x 5 columns]

# %%
result1_0.sort_values(['rmse'],ascending = True)
# Out:
#     epochs  learning_rates activation_function  regularizers      rmse
# 54    40.0         0.01000                relu           0.0  0.031769
# 40    30.0         0.03000                relu           0.0  0.032070
# 56    40.0         0.03000                relu           0.0  0.033914
# 38    30.0         0.01000                relu           0.0  0.035674
# 36    30.0         0.10000                relu           0.0  0.035794
# ..     ...             ...                 ...           ...       ...
# 1     10.0         1.00000             sigmoid           0.0  0.530202
# 30    20.0         0.00001                relu           0.0  0.531201
# 63    40.0         0.00001             sigmoid           0.0  0.559052
# 31    20.0         0.00001             sigmoid           0.0  0.865700
# 0     10.0         1.00000                relu           0.0  1.409797
#
# [64 rows x 5 columns]

# %% [markdown]
# # Model2  with 2 hidden layers and without regularization

# %%
def model_2(X_train,y_train,epochs_,activations,learning):
    model2 = tf.keras.Sequential()
    model2.add(tf.keras.layers.Flatten(input_shape=[14],name ="Input_Layer"))  
    model2.add(tf.keras.layers.Dense(128,activation = activations,name = "Hidden_Layer_1"))
    model2.add(tf.keras.layers.Dense(64,activation = activations,name = "Hidden_Layer_2"))
    model2.add(tf.keras.layers.Dense(1,activation = "linear",kernel_initializer='normal',name = "Output_Layer"))

    opt = tf.keras.optimizers.Adam(learning_rate=learning)

    model2.compile(loss='mean_squared_error', optimizer=opt, metrics = tf.keras.metrics.RootMeanSquaredError())

    model2.fit(X_train,y_train,epochs =epochs_,validation_data=(X_valid, y_valid))

    return model2.evaluate(X_test,y_test)[1]

# %%
result2_0 = pd.DataFrame(data)
result2_0.columns
# Out:
# Index(['epochs', 'learning_rates', 'activation_function', 'regularizers',
#        'rmse'],
#       dtype='object')

# %%
for epochs in [10,20,30,40]:
  for l in [1, 0.3, 0.1, 0.01,0.03,0.001,0.0001,0.00001]:
    for activations in ['relu','sigmoid']:
      
      rmse = model_2(X_train,y_train,epochs,activations,l)
      result2_0.loc[len(result2_0.index)] = [epochs,l,activations,0,rmse]
# Out:
# Epoch 1/10
# 6/6 [==============================] - 1s 32ms/step - loss: 10001628.0000 - root_mean_squared_error: 3162.5349 - val_loss: 174.4848 - val_root_mean_squared_error: 13.2093
# Epoch 2/10
# 6/6 [==============================] - 0s 9ms/step - loss: 168.0394 - root_mean_squared_error: 12.9630 - val_loss: 6.6293 - val_root_mean_squared_error: 2.5748
# Epoch 3/10
# 6/6 [==============================] - 0s 7ms/step - loss: 45.0004 - root_mean_squared_error: 6.7082 - val_loss: 45.1224 - val_root_mean_squared_error: 6.7173
# Epoch 4/10
# 6/6 [==============================] - 0s 7ms/step - loss: 21.9713 - root_mean_squared_error: 4.6874 - val_loss: 46.5892 - val_root_mean_squared_error: 6.8256
# Epoch 5/10
# 6/6 [==============================] - 0s 8ms/step - loss: 18.4364 - root_mean_squared_error: 4.2938 - val_loss: 22.3491 - val_root_mean_squared_error: 4.7275
# Epoch 6/10
# ...

# %%
result2_0.sort_values(['rmse'],ascending=True)
# Out:
#     epochs  learning_rates activation_function  regularizers      rmse
# 54    40.0         0.01000                relu           0.0  0.032176
# 36    30.0         0.10000                relu           0.0  0.034569
# 22    20.0         0.01000                relu           0.0  0.036311
# 52    40.0         0.10000                relu           0.0  0.036726
# 40    30.0         0.03000                relu           0.0  0.038634
# ..     ...             ...                 ...           ...       ...
# 31    20.0         0.00001             sigmoid           0.0  0.479125
# 0     10.0         1.00000                relu           0.0  0.795801
# 1     10.0         1.00000             sigmoid           0.0  1.683400
# 32    30.0         1.00000                relu           0.0  3.315039
# 16    20.0         1.00000                relu           0.0  4.649230
#
# [64 rows x 5 columns]

# %% [markdown]
# # Model3 with 3 hidden layers without reularization

# %%
def model_3(X_train,y_train,epochs_,activations,learning):
    model3 = tf.keras.Sequential()
    model3.add(tf.keras.layers.Flatten(input_shape=[14],name ="Input_Layer"))  
    model3.add(tf.keras.layers.Dense(128,activation = activations,name = "Hidden_Layer_1"))
    model3.add(tf.keras.layers.Dense(64,activation = activations,name = "Hidden_Layer_2"))
    model3.add(tf.keras.layers.Dense(32,activation = activations,name = "Hidden_Layer_3"))
    model3.add(tf.keras.layers.Dense(1,activation = "linear",kernel_initializer='normal',name = "Output_Layer"))

    opt = tf.keras.optimizers.Adam(learning_rate=learning)

    model3.compile(loss='mean_squared_error', optimizer=opt, metrics = tf.keras.metrics.RootMeanSquaredError())

    model3.fit(X_train,y_train,epochs =epochs_,validation_data=(X_valid, y_valid))

    return model3.evaluate(X_test,y_test)[1]

# %%
result3_0 = pd.DataFrame(data)
result3_0
# Out:
# Empty DataFrame
# Columns: [epochs, learning_rates, activation_function, regularizers, rmse]
# Index: []

# %%
for epochs in [10,20,30,40]:
  for l in [1, 0.3, 0.1, 0.01,0.03,0.001,0.0001,0.00001]:
    for activations in ['relu','sigmoid']:
      
      rmse = model_2(X_train,y_train,epochs,activations,l)
      result3_0.loc[len(result3_0.index)] = [epochs,l,activations,0,rmse]
# Out:
# Epoch 1/10
# 6/6 [==============================] - 1s 31ms/step - loss: 9401335.0000 - root_mean_squared_error: 3066.1597 - val_loss: 566.4290 - val_root_mean_squared_error: 23.7998
# Epoch 2/10
# 6/6 [==============================] - 0s 7ms/step - loss: 140.9012 - root_mean_squared_error: 11.8702 - val_loss: 71.6267 - val_root_mean_squared_error: 8.4633
# Epoch 3/10
# 6/6 [==============================] - 0s 7ms/step - loss: 29.1658 - root_mean_squared_error: 5.4005 - val_loss: 52.6751 - val_root_mean_squared_error: 7.2578
# Epoch 4/10
# 6/6 [==============================] - 0s 7ms/step - loss: 21.1158 - root_mean_squared_error: 4.5952 - val_loss: 28.4404 - val_root_mean_squared_error: 5.3330
# Epoch 5/10
# 6/6 [==============================] - 0s 7ms/step - loss: 13.1175 - root_mean_squared_error: 3.6218 - val_loss: 13.9864 - val_root_mean_squared_error: 3.7398
# Epoch 6/10
# ...

# %%
result3_0.sort_values(['rmse'],ascending=True)
# Out:
#     epochs  learning_rates activation_function  regularizers      rmse
# 24    20.0            0.03                relu           0.0  0.032383
# 40    30.0            0.03                relu           0.0  0.032516
# 54    40.0            0.01                relu           0.0  0.032988
# 55    40.0            0.01             sigmoid           0.0  0.033043
# 38    30.0            0.01                relu           0.0  0.037606
# ..     ...             ...                 ...           ...       ...
# 0     10.0            1.00                relu           0.0  0.820531
# 1     10.0            1.00             sigmoid           0.0  1.465574
# 48    40.0            1.00                relu           0.0  3.219512
# 32    30.0            1.00                relu           0.0  4.044563
# 16    20.0            1.00                relu           0.0  4.351256
#
# [64 rows x 5 columns]

# %% [markdown]
# # WITH REGULARIZER : L1,L2

# %% [markdown]
# # Model1 with 1 hidden layer and regulaizations : L1,L2

# %%
def model_1_R(X_train,y_train,epochs_,activations,learning,regularizer):
    model1 = tf.keras.Sequential()
    model1.add(tf.keras.layers.Flatten(input_shape=[14],name ="Input_Layer"))  
    model1.add(tf.keras.layers.Dense(128,activation = activations,kernel_regularizer=regularizer,name = "Hidden_Layer_1"))
    model1.add(tf.keras.layers.Dense(1,activation = "linear",kernel_initializer='normal',name = "Output_Layer"))

    opt = tf.keras.optimizers.Adam(learning_rate=learning)

    model1.compile(loss='mean_squared_error', optimizer=opt, metrics = tf.keras.metrics.RootMeanSquaredError())

    model1.fit(X_train,y_train,epochs =epochs_,validation_data=(X_valid, y_valid))

    return model1.evaluate(X_test,y_test)[1]

# %%
epoch_values = []
l_values = []
activ_values = []
rmses = []
regularizerss = []

# %%
data = {
    'epochs' : epoch_values,
    'learning_rates' : l_values,
    'activation_function':activ_values,    
    'regularizers' : regularizerss,
    'rmse' : rmses

}

# %%
data
# Out:
# {'activation_function': [],
#  'epochs': [],
#  'learning_rates': [],
#  'regularizers': [],
#  'rmse': []}

# %%
result1_1 = pd.DataFrame(data)
result1_1.columns
# Out:
# Index(['epochs', 'learning_rates', 'activation_function', 'regularizers',
#        'rmse'],
#       dtype='object')

# %%
for epochs in [10,20,30,40]:
  for l in [1, 0.3, 0.1, 0.01,0.03,0.001,0.0001,0.00001]:
    for activations in ['relu','sigmoid']:
      for regularizers in ['l1','l2']:      
        rmse = model_1_R(X_train,y_train,epochs,activations,l,regularizers)
        result1_1.loc[len(result1_1.index)] = [epochs,l,activations,regularizers,rmse]
# Out:
# Streaming output truncated to the last 5000 lines.
# 6/6 [==============================] - 0s 9ms/step - loss: 0.5157 - root_mean_squared_error: 0.1439 - val_loss: 0.4839 - val_root_mean_squared_error: 0.1410
# Epoch 20/20
# ...
# 2/2 [==============================] - 0s 12ms/step - loss: 0.4336 - root_mean_squared_error: 0.1316
# Epoch 1/20
# 6/6 [==============================] - 1s 33ms/step - loss: 0.3930 - root_mean_squared_error: 0.3784 - val_loss: 0.3363 - val_root_mean_squared_error: 0.3056
# Epoch 2/20
# 6/6 [==============================] - 0s 9ms/step - loss: 0.2959 - root_mean_squared_error: 0.2394 - val_loss: 0.2669 - val_root_mean_squared_error: 0.1885
# Epoch 3/20
# 6/6 [==============================] - 0s 9ms/step - loss: 0.2526 - root_mean_squared_error: 0.1605 - val_loss: 0.2448 - val_root_mean_squared_error: 0.1604
# Epoch 4/20
# ...

# %%
result1_1.sort_values(['rmse'],ascending=True)
# Out:
#      epochs  learning_rates activation_function regularizers      rmse
# 77     30.0         0.01000                relu           l2  0.033330
# 108    40.0         0.01000                relu           l1  0.037646
# 72     30.0         0.10000                relu           l1  0.042965
# 80     30.0         0.03000                relu           l1  0.043226
# 76     30.0         0.01000                relu           l1  0.044044
# ..      ...             ...                 ...          ...       ...
# 63     20.0         0.00001             sigmoid           l2  0.573976
# 126    40.0         0.00001             sigmoid           l1  0.584039
# 30     10.0         0.00001             sigmoid           l1  0.800537
# 1      10.0         1.00000                relu           l2  0.807548
# 0      10.0         1.00000                relu           l1  0.978284
#
# [128 rows x 5 columns]

# %% [markdown]
# # Model2 with 2 Hidden Layers with regularization L1,L2

# %%
def model_2_R(X_train,y_train,epochs_,activations,learning,regularizer):
    model2 = tf.keras.Sequential()
    model2.add(tf.keras.layers.Flatten(input_shape=[14],name ="Input_Layer"))  
    model2.add(tf.keras.layers.Dense(128,activation = activations,kernel_regularizer=regularizer,name = "Hidden_Layer_1"))
    model2.add(tf.keras.layers.Dense(64,activation = activations,kernel_regularizer=regularizer,name = "Hidden_Layer_2"))
    model2.add(tf.keras.layers.Dense(1,activation = "linear",kernel_initializer='normal',name = "Output_Layer"))

    opt = tf.keras.optimizers.Adam(learning_rate=learning)

    model2.compile(loss='mean_squared_error', optimizer=opt, metrics = tf.keras.metrics.RootMeanSquaredError())

    model2.fit(X_train,y_train,epochs =epochs_,validation_data=(X_valid, y_valid))

    return model2.evaluate(X_test,y_test)[1]

# %%
result2_1 = pd.DataFrame(data)
result2_1.columns
# Out:
# Index(['epochs', 'learning_rates', 'activation_function', 'regularizers',
#        'rmse'],
#       dtype='object')

# %%
for epochs in [10,20,30,40]:
  for l in [1, 0.3, 0.1, 0.01,0.03,0.001,0.0001,0.00001]:
    for activations in ['relu','sigmoid']:
      for regularizers in ['l1','l2']:      
        rmse = model_2_R(X_train,y_train,epochs,activations,l,regularizers)
        result2_1.loc[len(result2_1.index)] = [epochs,l,activations,regularizers,rmse]
# Out:
# Streaming output truncated to the last 5000 lines.
# 6/6 [==============================] - 0s 9ms/step - loss: 1.6173 - root_mean_squared_error: 0.1717 - val_loss: 1.4691 - val_root_mean_squared_error: 0.1708
# Epoch 20/20
# ...
# 2/2 [==============================] - 0s 10ms/step - loss: 1.2436 - root_mean_squared_error: 0.1548
# Epoch 1/20
# 6/6 [==============================] - 1s 58ms/step - loss: 1.2395 - root_mean_squared_error: 0.4077 - val_loss: 1.1643 - val_root_mean_squared_error: 0.3809
# Epoch 2/20
# 6/6 [==============================] - 0s 13ms/step - loss: 1.0906 - root_mean_squared_error: 0.3206 - val_loss: 1.0139 - val_root_mean_squared_error: 0.2765
# Epoch 3/20
# 6/6 [==============================] - 0s 12ms/step - loss: 0.9557 - root_mean_squared_error: 0.2190 - val_loss: 0.8923 - val_root_mean_squared_error: 0.1789
# Epoch 4/20
# ...

# %%
result2_1.sort_values(['rmse'],ascending = True)
# Out:
#      epochs  learning_rates activation_function regularizers      rmse
# 72     30.0            0.10                relu           l1  0.037797
# 109    40.0            0.01                relu           l2  0.057810
# 41     20.0            0.10                relu           l2  0.060591
# 77     30.0            0.01                relu           l2  0.061296
# 113    40.0            0.03                relu           l2  0.076820
# ..      ...             ...                 ...          ...       ...
# 0      10.0            1.00                relu           l1  2.367403
# 3      10.0            1.00             sigmoid           l2  2.629057
# 99     40.0            1.00             sigmoid           l2  2.653793
# 34     20.0            1.00             sigmoid           l1  4.575006
# 35     20.0            1.00             sigmoid           l2  4.692766
#
# [128 rows x 5 columns]

# %% [markdown]
# # Model3 with 3 Hidden Layers with regularization L1,L2

# %%
def model_3_R(X_train,y_train,epochs_,activations,learning,regularizer):
    model3 = tf.keras.Sequential()
    model3.add(tf.keras.layers.Flatten(input_shape=[14],name ="Input_Layer"))  
    model3.add(tf.keras.layers.Dense(128,activation = activations,kernel_regularizer=regularizer,name = "Hidden_Layer_1"))
    model3.add(tf.keras.layers.Dense(64,activation = activations,kernel_regularizer=regularizer,name = "Hidden_Layer_2"))
    model3.add(tf.keras.layers.Dense(32,activation = activations,kernel_regularizer=regularizer,name = "Hidden_Layer_3"))
    model3.add(tf.keras.layers.Dense(1,activation = "linear",kernel_initializer='normal',name = "Output_Layer"))

    opt = tf.keras.optimizers.Adam(learning_rate=learning)

    model3.compile(loss='mean_squared_error', optimizer=opt, metrics = tf.keras.metrics.RootMeanSquaredError())

    model3.fit(X_train,y_train,epochs =epochs_,validation_data=(X_valid, y_valid))

    return model3.evaluate(X_test,y_test)[1]

# %%
result3_1 = pd.DataFrame(data)
result3_1
# Out:
# Empty DataFrame
# Columns: [epochs, learning_rates, activation_function, regularizers, rmse]
# Index: []

# %%
for epochs in [10,20,30,40]:
  for l in [1, 0.3, 0.1, 0.01,0.03,0.001,0.0001,0.00001]:
    for activations in ['relu','sigmoid']:
      for regularizers in ['l1','l2']:      
        rmse = model_3_R(X_train,y_train,epochs,activations,l,regularizers)
        result3_1.loc[len(result3_1.index)] = [epochs,l,activations,regularizers,rmse]
# Out:
# Streaming output truncated to the last 5000 lines.
# 6/6 [==============================] - 0s 10ms/step - loss: 2.4329 - root_mean_squared_error: 0.1821 - val_loss: 2.2467 - val_root_mean_squared_error: 0.1871
# Epoch 20/20
# ...
# 2/2 [==============================] - 0s 5ms/step - loss: 1.9518 - root_mean_squared_error: 0.1539
# Epoch 1/20
# 6/6 [==============================] - 1s 38ms/step - loss: 1.7049 - root_mean_squared_error: 0.4529 - val_loss: 1.6280 - val_root_mean_squared_error: 0.4516
# Epoch 2/20
# 6/6 [==============================] - 0s 9ms/step - loss: 1.5407 - root_mean_squared_error: 0.4016 - val_loss: 1.4723 - val_root_mean_squared_error: 0.4055
# Epoch 3/20
# 6/6 [==============================] - 0s 9ms/step - loss: 1.3931 - root_mean_squared_error: 0.3560 - val_loss: 1.3208 - val_root_mean_squared_error: 0.3470
# Epoch 4/20
# ...

# %%
result3_1.sort_values(['rmse'],ascending = True)
# Out:
#      epochs  learning_rates activation_function regularizers       rmse
# 100    40.0           0.300                relu           l1   0.044939
# 109    40.0           0.010                relu           l2   0.078677
# 45     20.0           0.010                relu           l2   0.094658
# 77     30.0           0.010                relu           l2   0.108438
# 117    40.0           0.001                relu           l2   0.125353
# ..      ...             ...                 ...          ...        ...
# 2      10.0           1.000             sigmoid           l1   1.812338
# 33     20.0           1.000                relu           l2   2.230041
# 96     40.0           1.000                relu           l1   4.703168
# 97     40.0           1.000                relu           l2   5.284879
# 1      10.0           1.000                relu           l2  18.202639
#
# [128 rows x 5 columns]

# %% [markdown]
# ## result1_0 indicates the Model1 without regularization
# ## result2_0 indicates the Model2 without regularization
# ## result3_0 indicates the Model3 without regularization
# ## result1_1 indicates the Model1 with regularization L1,L2
# ## result2_1 indicates the Model2 with regularization L1,L2
# ## result3_1 indicates the Model3 with regularization L1,L2

# %% [markdown]
# ### These are best models

# %%
print(result1_0.sort_values(['rmse'],ascending = True).head(2))
print("------------------------------------------------------------")
print(result2_0.sort_values(['rmse'],ascending = True).head(2))
print("------------------------------------------------------------")
print(result3_0.sort_values(['rmse'],ascending = True).head(2))
print("------------------------------------------------------------")
print(result1_1.sort_values(['rmse'],ascending = True).head(2))
print("------------------------------------------------------------")
print(result2_1.sort_values(['rmse'],ascending = True).head(2))
print("------------------------------------------------------------")
print(result3_1.sort_values(['rmse'],ascending = True).head(2))
print("------------------------------------------------------------")
# Out:
#     epochs  learning_rates activation_function  regularizers      rmse
# 54    40.0            0.01                relu           0.0  0.031769
# 40    30.0            0.03                relu           0.0  0.032070
# ------------------------------------------------------------
#     epochs  learning_rates activation_function  regularizers      rmse
# 54    40.0            0.01                relu           0.0  0.032176
# 36    30.0            0.10                relu           0.0  0.034569
# ------------------------------------------------------------
#     epochs  learning_rates activation_function  regularizers      rmse
# 24    20.0            0.03                relu           0.0  0.032383
# 40    30.0            0.03                relu           0.0  0.032516
# ------------------------------------------------------------
#      epochs  learning_rates activation_function regularizers      rmse
# 77     30.0            0.01                relu           l2  0.033330
# ...

# %% [markdown]
# ### Among all the models compacted in the tables
# ### Best models are with low error(root mean square error)

# %% [markdown]
# ## Best model is with values : epochs = 40,l = 0.01,'relu',no regularization

# %%
model1 = tf.keras.Sequential()
model1.add(tf.keras.layers.Flatten(input_shape=[14],name ="Input_Layer"))  
model1.add(tf.keras.layers.Dense(128,activation = activations,name = "Hidden_Layer_1"))
model1.add(tf.keras.layers.Dense(1,activation = "linear",kernel_initializer='normal',name = "Output_Layer"))

opt = tf.keras.optimizers.Adam(learning_rate=0.01)

history = model1.compile(loss='mean_squared_error', optimizer=opt, metrics = tf.keras.metrics.RootMeanSquaredError())

model1.fit(X_train,y_train,epochs =40,validation_data=(X_valid, y_valid))
# Out:
# Epoch 1/40
# 6/6 [==============================] - 0s 30ms/step - loss: 0.2418 - root_mean_squared_error: 0.4917 - val_loss: 0.0937 - val_root_mean_squared_error: 0.3062
# Epoch 2/40
# 6/6 [==============================] - 0s 9ms/step - loss: 0.0986 - root_mean_squared_error: 0.3139 - val_loss: 0.0443 - val_root_mean_squared_error: 0.2104
# Epoch 3/40
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0663 - root_mean_squared_error: 0.2576 - val_loss: 0.0456 - val_root_mean_squared_error: 0.2136
# Epoch 4/40
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0392 - root_mean_squared_error: 0.1980 - val_loss: 0.0205 - val_root_mean_squared_error: 0.1432
# Epoch 5/40
# 6/6 [==============================] - 0s 10ms/step - loss: 0.0295 - root_mean_squared_error: 0.1718 - val_loss: 0.0216 - val_root_mean_squared_error: 0.1468
# Epoch 6/40
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_style("darkgrid")
#get the details form the history object
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(acc) + 1)

#Train and validation accuracy
plt.plot(epochs, acc, 'b', label='Training accurarcy')
plt.plot(epochs, val_acc, 'r', label='Validation accurarcy')
plt.xlabel('Epoch #')
plt.ylabel('accuracy')
plt.title('Training and Validation accurarcy')
plt.legend()


plt.figure()
#Train and validation loss
plt.plot(epochs, loss, 'b', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.xlabel('Epoch #')
plt.ylabel('loss')
plt.title('Training and Validation loss')
plt.legend()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-99-357eec617ecb> in <module>()
#       3 sns.set_style("darkgrid")
#       4 #get the details form the history object
# ----> 5 acc = history.history['accuracy']
#       6 val_acc = history.history['val_accuracy']
#       7 loss = history.history['loss']
#
# AttributeError: 'NoneType' object has no attribute 'history'
